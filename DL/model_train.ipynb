# %%
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, models, transforms
from dataset import Dataset
from torch.utils.data import DataLoader

import os
import cv2
import numpy as np

from time import time
from visdom import Visdom
import copy

# Define important global variables 
# Change 'pretrained' variable to decide to get the pretrained weight or not
# Change 'feature_extract' variable to decide to keep all layers to update or freeze a part of the model
num_classes = 10
batch_size = 256
num_epochs = 15
feature_extract = True
pretrained = True
num_epochs = 1000
input_size = 224

# Use Visdom to visualise the training progress
viz = Visdom()
step_list = [0]
win = viz.line(X=np.array([0]), Y=np.array([1.0]), opts=dict(title='loss'))
# Out:
# Setting up a new session...

# %%
# This function is used to tell the optimizer not to update params in the freeze layer 
# Only use in freeze mode
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs):
    since = time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 1000.0

    count = 0
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        model.train()  # Set model to training mode
        
        running_loss = 0.0
        running_corrects = 0

        count += 1
        # Iterate over data.
        for step, (inputs, labels) in enumerate(dataloaders):
            inputs = inputs.cuda()
            labels = labels.cuda()

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward pass and calculate loss
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            _, preds = torch.max(outputs, 1)

            # Back prop and update params
            loss.backward()
            optimizer.step()

            # statistics
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels)

            if step % 1 == 0:
                step_list.append(step_list[-1] + 1)
                viz.line(X=np.array([step_list[-1]]), Y=np.array([loss.item()]), win=win, update='append')
                
            if step % 100 == 0:    
                print('     step:{}, loss:{:.3f}, time:{:.3f} min'
                    .format(step, loss.item(), (time() - since) / 60))

        # deep copy the model
        if loss.item() < best_acc:
            count = 0
            best_acc = loss.item()
            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), './model/net{}-{:.3f}.pth'.format(epoch, loss))

        if count == 10:
            break
        print()

    time_elapsed = time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
BASE_DIR = './data/'
impath = os.listdir(BASE_DIR + 'train')

# Load data
train_ds = Dataset(BASE_DIR)
train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True)

# Init model and customize from the pretrained version in Pytorch
model = models.vgg11_bn(pretrained=pretrained).cuda()
set_parameter_requires_grad(model, feature_extract)
num_ftrs = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_ftrs,num_classes)
model =  torch.nn.DataParallel(model).cuda()

loss_fn = torch.nn.CrossEntropyLoss()

# Choose params to update 
params_to_update = model.parameters()
if feature_extract:
    params_to_update = []
    for name,param in model.named_parameters():
        if param.requires_grad == True:
            params_to_update.append(param)
            
optimizer = torch.optim.SGD(params_to_update, lr=0.001, momentum=0.9)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg11_bn-6002323d.pth" to /home/avitech-pc4/.cache/torch/hub/checkpoints/vgg11_bn-6002323d.pth
# 100%|██████████| 507M/507M [02:41<00:00, 3.30MB/s]
# Params to learn:

# %%
model_ft = train_model(model, train_dl, loss_fn, optimizer, num_epochs=num_epochs)
# Out:
# Epoch 0/999
# ----------
#      step:0, loss:2.336, time:0.009 min
#      step:100, loss:1.115, time:0.818 min
#      step:200, loss:0.905, time:1.627 min
#
# Epoch 1/999
# ----------
#      step:0, loss:0.880, time:1.915 min
#      step:100, loss:0.679, time:2.724 min
#      step:200, loss:0.731, time:3.534 min
#
# Epoch 2/999
# ----------
#      step:0, loss:0.693, time:3.824 min
#      step:100, loss:0.625, time:4.641 min
#      step:200, loss:0.841, time:5.456 min
#
# Epoch 3/999
# ----------
#      step:0, loss:0.627, time:5.749 min
#      step:100, loss:0.637, time:6.562 min
#      step:200, loss:0.649, time:7.383 min
#
# Epoch 4/999
# ----------
#      step:0, loss:0.738, time:7.676 min
#      step:100, loss:0.650, time:8.496 min
#      step:200, loss:0.624, time:9.318 min
#
# Epoch 5/999
# ----------
#      step:0, loss:0.627, time:9.604 min
#      step:100, loss:0.711, time:10.423 min
#      step:200, loss:0.552, time:11.246 min
#
# Epoch 6/999
# ----------
#      step:0, loss:0.512, time:11.529 min
#      step:100, loss:0.671, time:12.354 min
#      step:200, loss:0.513, time:13.207 min
#
# Epoch 7/999
# ----------
#      step:0, loss:0.585, time:13.513 min
#      step:100, loss:0.636, time:14.369 min
#      step:200, loss:0.570, time:15.228 min
#
# Epoch 8/999
# ----------
#      step:0, loss:0.605, time:15.524 min
#      step:100, loss:0.570, time:16.382 min
#      step:200, loss:0.567, time:17.236 min
#
# Epoch 9/999
# ----------
#      step:0, loss:0.546, time:17.528 min
#      step:100, loss:0.656, time:18.386 min
#      step:200, loss:0.612, time:19.240 min
#
# Epoch 10/999
# ----------
#      step:0, loss:0.513, time:19.530 min
#      step:100, loss:0.546, time:20.360 min
#      step:200, loss:0.619, time:21.189 min
#
# Epoch 11/999
# ----------
#      step:0, loss:0.614, time:21.476 min
#      step:100, loss:0.515, time:22.309 min
#      step:200, loss:0.534, time:23.148 min
#
# Epoch 12/999
# ----------
#      step:0, loss:0.540, time:23.437 min
#      step:100, loss:0.566, time:24.266 min
#      step:200, loss:0.589, time:25.081 min
#
# Epoch 13/999
# ----------
#      step:0, loss:0.594, time:25.360 min
#      step:100, loss:0.438, time:26.174 min
#      step:200, loss:0.583, time:26.991 min
#
# Epoch 14/999
# ----------
#      step:0, loss:0.542, time:27.271 min
#      step:100, loss:0.519, time:28.087 min
#      step:200, loss:0.595, time:28.905 min
#
# Epoch 15/999
# ----------
#      step:0, loss:0.598, time:29.199 min
#      step:100, loss:0.583, time:30.018 min
#      step:200, loss:0.611, time:30.834 min
#
# Epoch 16/999
# ----------
#      step:0, loss:0.600, time:31.116 min
#      step:100, loss:0.558, time:31.937 min
#      step:200, loss:0.538, time:32.758 min
#
# Epoch 17/999
# ----------
#      step:0, loss:0.439, time:33.040 min
#      step:100, loss:0.509, time:33.863 min
#      step:200, loss:0.558, time:34.688 min
#
# Epoch 18/999
# ----------
#      step:0, loss:0.496, time:34.976 min
#      step:100, loss:0.453, time:35.834 min
#      step:200, loss:0.456, time:36.688 min
#
# Epoch 19/999
# ----------
#      step:0, loss:0.545, time:36.980 min
#      step:100, loss:0.522, time:37.838 min
#      step:200, loss:0.502, time:38.694 min
#
# Epoch 20/999
# ----------
#      step:0, loss:0.634, time:38.988 min
#      step:100, loss:0.645, time:39.841 min
#      step:200, loss:0.545, time:40.691 min
#
# Epoch 21/999
# ----------
#      step:0, loss:0.541, time:40.987 min
#      step:100, loss:0.495, time:41.846 min
#      step:200, loss:0.557, time:42.701 min
#
# Epoch 22/999
# ----------
#      step:0, loss:0.566, time:42.992 min
#      step:100, loss:0.534, time:43.840 min
#      step:200, loss:0.454, time:44.700 min
#
# Epoch 23/999
# ----------
#      step:0, loss:0.485, time:44.996 min
#      step:100, loss:0.619, time:45.905 min
#      step:200, loss:0.584, time:47.159 min
#
# Epoch 24/999
# ----------
#      step:0, loss:0.501, time:47.607 min
#      step:100, loss:0.528, time:48.892 min
#      step:200, loss:0.483, time:50.203 min
#
# Epoch 25/999
# ----------
#      step:0, loss:0.456, time:50.641 min
#      step:100, loss:0.471, time:51.908 min
#      step:200, loss:0.474, time:53.183 min
#
# Epoch 26/999
# ----------
#      step:0, loss:0.575, time:53.621 min
#      step:100, loss:0.570, time:54.899 min
#      step:200, loss:0.571, time:56.184 min
#
# Epoch 27/999
# ----------
#      step:0, loss:0.503, time:56.621 min
#      step:100, loss:0.462, time:57.887 min
#      step:200, loss:0.580, time:59.159 min
#
# Epoch 28/999
# ----------
#      step:0, loss:0.533, time:59.597 min
#      step:100, loss:0.536, time:60.871 min
#      step:200, loss:0.602, time:62.166 min
#
# Epoch 29/999
# ----------
#      step:0, loss:0.558, time:62.614 min
#      step:100, loss:0.517, time:63.874 min
#      step:200, loss:0.556, time:65.128 min
#
# Epoch 30/999
# ----------
#      step:0, loss:0.565, time:65.577 min
#      step:100, loss:0.525, time:66.839 min
#      step:200, loss:0.558, time:68.111 min
#
# Epoch 31/999
# ----------
#      step:0, loss:0.511, time:68.552 min
#      step:100, loss:0.556, time:69.846 min
#      step:200, loss:0.519, time:71.118 min
#
# Epoch 32/999
# ----------
#      step:0, loss:0.576, time:71.551 min
#      step:100, loss:0.437, time:72.838 min
#      step:200, loss:0.538, time:74.203 min
#
# Epoch 33/999
# ----------
#      step:0, loss:0.550, time:74.677 min
#      step:100, loss:0.566, time:76.058 min
#      step:200, loss:0.578, time:77.465 min
#
# Epoch 34/999
# ----------
#      step:0, loss:0.416, time:77.954 min
#      step:100, loss:0.519, time:79.359 min
#      step:200, loss:0.553, time:80.781 min
#
# Epoch 35/999
# ----------
#      step:0, loss:0.542, time:81.270 min
#      step:100, loss:0.536, time:82.705 min
#      step:200, loss:0.511, time:84.100 min
#
# Epoch 36/999
# ----------
#      step:0, loss:0.523, time:84.594 min
#      step:100, loss:0.429, time:85.942 min
#      step:200, loss:0.492, time:87.204 min
#
# Epoch 37/999
# ----------
#      step:0, loss:0.540, time:87.665 min
#      step:100, loss:0.541, time:88.947 min
#      step:200, loss:0.554, time:90.243 min
#
# Epoch 38/999
# ----------
#      step:0, loss:0.540, time:90.702 min
#      step:100, loss:0.529, time:91.977 min
#      step:200, loss:0.541, time:93.255 min
#
# Epoch 39/999
# ----------
#      step:0, loss:0.601, time:93.740 min
#      step:100, loss:0.631, time:95.004 min
#      step:200, loss:0.412, time:96.283 min
#
# Epoch 40/999
# ----------
#      step:0, loss:0.514, time:96.720 min
#      step:100, loss:0.593, time:98.034 min
#      step:200, loss:0.579, time:99.349 min
#
# Epoch 41/999
# ----------
#      step:0, loss:0.483, time:99.797 min
#      step:100, loss:0.537, time:101.101 min
#      step:200, loss:0.498, time:102.379 min
#
# Epoch 42/999
# ----------
#      step:0, loss:0.569, time:102.824 min
#      step:100, loss:0.512, time:104.133 min
#      step:200, loss:0.519, time:105.436 min
#
# Epoch 43/999
# ----------
#      step:0, loss:0.483, time:105.888 min
#      step:100, loss:0.515, time:107.207 min
#      step:200, loss:0.505, time:108.503 min
#
# Epoch 44/999
# ----------
#      step:0, loss:0.491, time:108.943 min
#      step:100, loss:0.537, time:110.227 min
#      step:200, loss:0.561, time:111.510 min
#
# Epoch 45/999
# ----------
#      step:0, loss:0.491, time:111.950 min
#      step:100, loss:0.433, time:113.282 min
#      step:200, loss:0.509, time:114.607 min
#
# Epoch 46/999
# ----------
#      step:0, loss:0.515, time:115.055 min
#      step:100, loss:0.465, time:116.361 min
#      step:200, loss:0.548, time:117.650 min
#
# Epoch 47/999
# ----------
#      step:0, loss:0.549, time:118.108 min
#      step:100, loss:0.465, time:119.478 min
#      step:200, loss:0.513, time:120.817 min
#
# Epoch 48/999
# ----------
#      step:0, loss:0.477, time:121.281 min
#      step:100, loss:0.478, time:122.596 min
#      step:200, loss:0.578, time:123.920 min
#
# Epoch 49/999
# ----------
#      step:0, loss:0.563, time:124.394 min
#      step:100, loss:0.521, time:125.706 min
#      step:200, loss:0.548, time:127.084 min
#
# Epoch 50/999
# ----------
#      step:0, loss:0.492, time:127.555 min
#      step:100, loss:0.500, time:128.915 min
#      step:200, loss:0.474, time:130.277 min
#
# Epoch 51/999
# ----------
#      step:0, loss:0.434, time:130.756 min
#      step:100, loss:0.539, time:132.151 min
#      step:200, loss:0.521, time:133.532 min
#
# Epoch 52/999
# ----------
#      step:0, loss:0.558, time:134.010 min
#      step:100, loss:0.474, time:135.354 min
#      step:200, loss:0.508, time:136.738 min
#
# Epoch 53/999
# ----------
#      step:0, loss:0.383, time:137.202 min
#      step:100, loss:0.549, time:138.541 min
#      step:200, loss:0.495, time:139.920 min
#
# Epoch 54/999
# ----------
#      step:0, loss:0.453, time:140.390 min
#      step:100, loss:0.568, time:141.756 min
#      step:200, loss:0.576, time:143.120 min
#
# Epoch 55/999
# ----------
#      step:0, loss:0.555, time:143.593 min
#      step:100, loss:0.456, time:144.985 min
#      step:200, loss:0.543, time:146.386 min
#
# Epoch 56/999
# ----------
#      step:0, loss:0.454, time:146.850 min
#      step:100, loss:0.518, time:148.231 min
#      step:200, loss:0.460, time:149.610 min
#
# Epoch 57/999
# ----------
#      step:0, loss:0.439, time:150.060 min
#      step:100, loss:0.517, time:151.398 min
#      step:200, loss:0.487, time:152.782 min
#
# Epoch 58/999
# ----------
#      step:0, loss:0.480, time:153.264 min
#      step:100, loss:0.473, time:154.634 min
#      step:200, loss:0.581, time:156.026 min
# Training complete in 156m 29s
# Best val Acc: 0.361137

# %%
# test_img = cv2.imread(BASE_DIR + 'train/0/1.jpg')
# test_img = cv2.resize(test_img, (input_size,input_size), interpolation=cv2.INTER_CUBIC)
# test_img = np.moveaxis(test_img,2,0)
# test_img = torch.FloatTensor(test_img).cuda().unsqueeze(0)
# print(test_img.shape)

# outputs = model(test_img)
# print(outputs.shape)
# print(outputs)
# Out:
# Connection to remote host was lost.
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
