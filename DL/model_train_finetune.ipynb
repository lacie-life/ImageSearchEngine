# %%
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, models, transforms
from dataset import Dataset
from torch.utils.data import DataLoader

import os
import cv2
import numpy as np

from time import time
from visdom import Visdom
import copy

model_name = "vgg11"
num_classes = 10
batch_size = 64
feature_extract = False
pretrained = True
num_epochs = 1000
input_size = 224

# 设置visdom
viz = Visdom()
step_list = [0]
win = viz.line(X=np.array([0]), Y=np.array([1.0]), opts=dict(title='loss'))
# Out:
# Setting up a new session...

# %%
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs):
    since = time()

    val_acc_history = []
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 1000.0

    count = 0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        model.train()  # Set model to training mode
        
        running_loss = 0.0
        running_corrects = 0

        count += 1
        # Iterate over data.
        for step, (inputs, labels) in enumerate(dataloaders):
            inputs = inputs.cuda()
            labels = labels.cuda()

            # zero the parameter gradients
            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            _, preds = torch.max(outputs, 1)

            loss.backward()
            optimizer.step()

            # statistics
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

            if step % 1 == 0:
                step_list.append(step_list[-1] + 1)
                viz.line(X=np.array([step_list[-1]]), Y=np.array([loss.item()]), win=win, update='append')
                
            if step % 100 == 0:    
                print('     step:{}, loss:{:.3f}, time:{:.3f} min'
                    .format(step, loss.item(), (time() - since) / 60))

        # deep copy the model
        if loss.item() < best_acc:
            count = 0
            best_acc = loss.item()
            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), './model/net_finetune{}-{:.3f}.pth'.format(epoch, loss))

        if count == 10:
            break
        print()

    time_elapsed = time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, val_acc_history

# %%
BASE_DIR = './data/'
impath = os.listdir(BASE_DIR + 'train')

train_ds = Dataset(BASE_DIR)
train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True)

# model = models.squeezenet1_0(pretrained = pretrained).cuda()
# set_parameter_requires_grad(model, feature_extract)
# model.classifier[1] = nn.Conv2d(512, num_classes, kernel_size=(1,1), stride=(1,1))
# model.num_classes = num_classes

model = models.vgg11_bn(pretrained=pretrained).cuda()
# set_parameter_requires_grad(model, feature_extract)
num_ftrs = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_ftrs,num_classes)

model =  torch.nn.DataParallel(model).cuda()

loss_fn = torch.nn.CrossEntropyLoss()

# params_to_update = model.parameters()
# print("Params to learn:")
# if feature_extract:
#     params_to_update = []
#     for name,param in model.named_parameters():
#         if param.requires_grad == True:
#             params_to_update.append(param)
# else:
#     for name,param in model.named_parameters():
#         if param.requires_grad == True:
#             print("\t",name)
            
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# %%
model_ft, hist = train_model(model, train_dl, loss_fn, optimizer, num_epochs=num_epochs)
# Out:
# Epoch 0/999
# ----------
#      step:0, loss:2.341, time:0.006 min
#      step:100, loss:0.496, time:0.471 min
#      step:200, loss:0.350, time:0.944 min
#      step:300, loss:0.408, time:1.417 min
#      step:400, loss:0.324, time:1.892 min
#      step:500, loss:0.350, time:2.361 min
#      step:600, loss:0.374, time:2.828 min
#      step:700, loss:0.389, time:3.295 min
#      step:800, loss:0.320, time:3.955 min
#      step:900, loss:0.308, time:4.436 min
#
# Epoch 1/999
# ----------
#      step:0, loss:0.174, time:4.627 min
#      step:100, loss:0.203, time:5.101 min
#      step:200, loss:0.206, time:5.866 min
#      step:300, loss:0.197, time:6.680 min
#      step:400, loss:0.087, time:7.500 min
#      step:500, loss:0.378, time:8.302 min
#      step:600, loss:0.273, time:9.115 min
#      step:700, loss:0.209, time:9.917 min
#      step:800, loss:0.100, time:10.726 min
#      step:900, loss:0.260, time:11.532 min
#
# Epoch 2/999
# ----------
#      step:0, loss:0.266, time:11.844 min
#      step:100, loss:0.152, time:12.641 min
#      step:200, loss:0.241, time:13.467 min
#      step:300, loss:0.129, time:14.266 min
#      step:400, loss:0.064, time:15.080 min
#      step:500, loss:0.115, time:15.879 min
#      step:600, loss:0.221, time:16.689 min
#      step:700, loss:0.154, time:17.504 min
#      step:800, loss:0.098, time:18.304 min
#      step:900, loss:0.226, time:19.104 min
#
# Epoch 3/999
# ----------
#      step:0, loss:0.187, time:19.408 min
#      step:100, loss:0.058, time:20.234 min
#      step:200, loss:0.089, time:21.052 min
#      step:300, loss:0.307, time:21.877 min
#      step:400, loss:0.141, time:22.690 min
#      step:500, loss:0.107, time:23.503 min
#      step:600, loss:0.069, time:24.318 min
#      step:700, loss:0.088, time:25.130 min
#      step:800, loss:0.140, time:25.935 min
#      step:900, loss:0.072, time:26.751 min
#
# Epoch 4/999
# ----------
#      step:0, loss:0.024, time:27.070 min
#      step:100, loss:0.077, time:27.886 min
#      step:200, loss:0.130, time:28.692 min
#      step:300, loss:0.047, time:29.502 min
#      step:400, loss:0.078, time:30.313 min
#      step:500, loss:0.094, time:31.119 min
#      step:600, loss:0.146, time:31.937 min
#      step:700, loss:0.081, time:32.753 min
#      step:800, loss:0.087, time:33.562 min
#      step:900, loss:0.143, time:34.358 min
#
# Epoch 5/999
# ----------
#      step:0, loss:0.057, time:34.683 min
#      step:100, loss:0.026, time:35.490 min
#      step:200, loss:0.052, time:36.295 min
#      step:300, loss:0.088, time:37.106 min
#      step:400, loss:0.131, time:37.901 min
#      step:500, loss:0.053, time:38.716 min
#      step:600, loss:0.049, time:39.527 min
#      step:700, loss:0.083, time:40.342 min
#      step:800, loss:0.027, time:41.163 min
#      step:900, loss:0.077, time:41.990 min
#
# Epoch 6/999
# ----------
#      step:0, loss:0.050, time:42.305 min
#      step:100, loss:0.041, time:43.112 min
#      step:200, loss:0.099, time:43.928 min
#      step:300, loss:0.008, time:44.742 min
#      step:400, loss:0.085, time:45.547 min
#      step:500, loss:0.067, time:46.361 min
#      step:600, loss:0.079, time:47.164 min
#      step:700, loss:0.027, time:47.989 min
#      step:800, loss:0.058, time:48.799 min
#      step:900, loss:0.025, time:49.602 min
#
# Epoch 7/999
# ----------
#      step:0, loss:0.004, time:49.911 min
#      step:100, loss:0.040, time:50.712 min
#      step:200, loss:0.037, time:51.527 min
#      step:300, loss:0.027, time:52.334 min
#      step:400, loss:0.018, time:53.147 min
#      step:500, loss:0.053, time:53.954 min
#      step:600, loss:0.050, time:54.758 min
#      step:700, loss:0.019, time:55.577 min
#      step:800, loss:0.043, time:56.378 min
#      step:900, loss:0.026, time:57.217 min
#
# Epoch 8/999
# ----------
#      step:0, loss:0.037, time:57.523 min
#      step:100, loss:0.029, time:58.326 min
#      step:200, loss:0.015, time:59.142 min
#      step:300, loss:0.042, time:59.962 min
#      step:400, loss:0.008, time:60.761 min
#      step:500, loss:0.020, time:61.590 min
#      step:600, loss:0.007, time:62.423 min
#      step:700, loss:0.102, time:63.227 min
#      step:800, loss:0.032, time:64.043 min
#      step:900, loss:0.095, time:64.859 min
#
# Epoch 9/999
# ----------
#      step:0, loss:0.014, time:65.173 min
#      step:100, loss:0.071, time:65.981 min
#      step:200, loss:0.008, time:66.811 min
#      step:300, loss:0.009, time:67.642 min
#      step:400, loss:0.007, time:68.486 min
#      step:500, loss:0.041, time:69.307 min
#      step:600, loss:0.011, time:70.129 min
#      step:700, loss:0.003, time:70.955 min
#      step:800, loss:0.065, time:71.771 min
#      step:900, loss:0.012, time:72.593 min
#
# Epoch 10/999
# ----------
#      step:0, loss:0.008, time:72.904 min
#      step:100, loss:0.010, time:73.718 min
#      step:200, loss:0.033, time:74.558 min
#      step:300, loss:0.004, time:75.368 min
#      step:400, loss:0.005, time:76.216 min
#      step:500, loss:0.005, time:77.042 min
#      step:600, loss:0.047, time:77.868 min
#      step:700, loss:0.007, time:78.737 min
#      step:800, loss:0.009, time:79.567 min
#      step:900, loss:0.003, time:80.401 min
#
# Epoch 11/999
# ----------
#      step:0, loss:0.024, time:80.715 min
#      step:100, loss:0.026, time:81.531 min
#      step:200, loss:0.014, time:82.349 min
#      step:300, loss:0.002, time:83.172 min
#      step:400, loss:0.001, time:83.989 min
#      step:500, loss:0.004, time:84.889 min
#      step:600, loss:0.005, time:85.816 min
#      step:700, loss:0.005, time:86.643 min
#      step:800, loss:0.003, time:87.592 min
#      step:900, loss:0.010, time:88.488 min
#
# Epoch 12/999
# ----------
#      step:0, loss:0.005, time:88.811 min
#      step:100, loss:0.009, time:89.619 min
#      step:200, loss:0.009, time:90.422 min
#      step:300, loss:0.002, time:91.221 min
#      step:400, loss:0.001, time:92.002 min
#      step:500, loss:0.002, time:92.835 min
#      step:600, loss:0.003, time:93.660 min
#      step:700, loss:0.002, time:94.466 min
#      step:800, loss:0.004, time:95.273 min
#      step:900, loss:0.001, time:96.087 min
#
# Epoch 13/999
# ----------
#      step:0, loss:0.007, time:96.404 min
#      step:100, loss:0.037, time:97.215 min
#      step:200, loss:0.000, time:98.035 min
#      step:300, loss:0.002, time:98.843 min
#      step:400, loss:0.018, time:99.681 min
#      step:500, loss:0.001, time:100.473 min
#      step:600, loss:0.005, time:101.300 min
#      step:700, loss:0.003, time:102.110 min
#      step:800, loss:0.005, time:102.927 min
#      step:900, loss:0.002, time:103.719 min
#
# Epoch 14/999
# ----------
#      step:0, loss:0.008, time:104.030 min
#      step:100, loss:0.023, time:104.829 min
#      step:200, loss:0.001, time:105.652 min
#      step:300, loss:0.005, time:106.476 min
#      step:400, loss:0.001, time:107.275 min
#      step:500, loss:0.004, time:108.066 min
#      step:600, loss:0.035, time:108.878 min
#      step:700, loss:0.001, time:109.664 min
#      step:800, loss:0.012, time:110.478 min
#      step:900, loss:0.001, time:111.290 min
#
# Epoch 15/999
# ----------
#      step:0, loss:0.004, time:111.593 min
#      step:100, loss:0.045, time:112.395 min
#      step:200, loss:0.009, time:113.196 min
#      step:300, loss:0.004, time:113.993 min
#      step:400, loss:0.002, time:114.843 min
#      step:500, loss:0.001, time:115.802 min
#      step:600, loss:0.004, time:116.607 min
#      step:700, loss:0.000, time:117.403 min
#      step:800, loss:0.009, time:118.178 min
#      step:900, loss:0.002, time:118.965 min
#
# Epoch 16/999
# ----------
#      step:0, loss:0.001, time:119.260 min
#      step:100, loss:0.001, time:120.063 min
#      step:200, loss:0.000, time:120.879 min
#      step:300, loss:0.003, time:121.675 min
#      step:400, loss:0.002, time:122.495 min
#      step:500, loss:0.001, time:123.304 min
#      step:600, loss:0.003, time:124.089 min
#      step:700, loss:0.000, time:124.892 min
#      step:800, loss:0.003, time:125.681 min
#      step:900, loss:0.006, time:126.477 min
#
# Epoch 17/999
# ----------
#      step:0, loss:0.001, time:126.779 min
#      step:100, loss:0.001, time:127.587 min
#      step:200, loss:0.001, time:128.519 min
#      step:300, loss:0.001, time:129.401 min
#      step:400, loss:0.002, time:130.189 min
#      step:500, loss:0.000, time:130.972 min
#      step:600, loss:0.002, time:131.785 min
#      step:700, loss:0.003, time:132.572 min
#      step:800, loss:0.000, time:133.360 min
#      step:900, loss:0.009, time:134.161 min
#
# Epoch 18/999
# ----------
#      step:0, loss:0.000, time:134.454 min
#      step:100, loss:0.002, time:135.258 min
#      step:200, loss:0.001, time:136.031 min
#      step:300, loss:0.000, time:136.815 min
#      step:400, loss:0.000, time:137.589 min
#      step:500, loss:0.001, time:138.374 min
#      step:600, loss:0.001, time:139.163 min
#      step:700, loss:0.000, time:139.959 min
#      step:800, loss:0.000, time:140.746 min
#      step:900, loss:0.001, time:141.576 min
#
# Epoch 19/999
# ----------
#      step:0, loss:0.001, time:141.874 min
#      step:100, loss:0.000, time:142.688 min
#      step:200, loss:0.001, time:143.491 min
#      step:300, loss:0.000, time:144.277 min
#      step:400, loss:0.002, time:145.086 min
#      step:500, loss:0.000, time:145.873 min
#      step:600, loss:0.002, time:146.669 min
#      step:700, loss:0.001, time:147.489 min
#      step:800, loss:0.000, time:148.266 min
#      step:900, loss:0.000, time:149.054 min
#
# Epoch 20/999
# ----------
#      step:0, loss:0.000, time:149.354 min
#      step:100, loss:0.000, time:150.135 min
#      step:200, loss:0.002, time:150.968 min
#      step:300, loss:0.000, time:151.821 min
#      step:400, loss:0.000, time:152.689 min
#      step:500, loss:0.009, time:153.553 min
#      step:600, loss:0.009, time:154.410 min
#      step:700, loss:0.004, time:155.255 min
#      step:800, loss:0.000, time:156.102 min
#      step:900, loss:0.008, time:156.967 min
#
# Epoch 21/999
# ----------
#      step:0, loss:0.000, time:157.295 min
#      step:100, loss:0.000, time:158.160 min
#      step:200, loss:0.009, time:158.991 min
#      step:300, loss:0.000, time:159.842 min
#      step:400, loss:0.000, time:160.684 min
#      step:500, loss:0.001, time:161.543 min
#      step:600, loss:0.000, time:162.413 min
#      step:700, loss:0.000, time:163.282 min
#      step:800, loss:0.003, time:164.135 min
#      step:900, loss:0.012, time:164.994 min
#
# Epoch 22/999
# ----------
#      step:0, loss:0.001, time:165.329 min
#      step:100, loss:0.001, time:166.187 min
#      step:200, loss:0.000, time:167.038 min
#      step:300, loss:0.001, time:167.885 min
#      step:400, loss:0.003, time:168.738 min
#      step:500, loss:0.000, time:169.578 min
#      step:600, loss:0.000, time:170.425 min
#      step:700, loss:0.001, time:171.266 min
#      step:800, loss:0.004, time:172.116 min
#      step:900, loss:0.003, time:172.956 min
#
# Epoch 23/999
# ----------
#      step:0, loss:0.001, time:173.271 min
#      step:100, loss:0.001, time:174.134 min
#      step:200, loss:0.001, time:174.986 min
#      step:300, loss:0.000, time:175.832 min
#      step:400, loss:0.001, time:176.677 min
#      step:500, loss:0.000, time:177.533 min
#      step:600, loss:0.034, time:178.375 min
#      step:700, loss:0.000, time:179.247 min
#      step:800, loss:0.002, time:180.109 min
#      step:900, loss:0.003, time:180.959 min
#
# Epoch 24/999
# ----------
#      step:0, loss:0.000, time:181.284 min
#      step:100, loss:0.000, time:182.138 min
#      step:200, loss:0.049, time:182.993 min
#      step:300, loss:0.000, time:183.854 min
#      step:400, loss:0.006, time:184.706 min
#      step:500, loss:0.001, time:185.564 min
#      step:600, loss:0.000, time:186.417 min
#      step:700, loss:0.001, time:187.266 min
#      step:800, loss:0.001, time:188.124 min
#      step:900, loss:0.001, time:188.993 min
#
# Epoch 25/999
# ----------
#      step:0, loss:0.001, time:189.313 min
#      step:100, loss:0.000, time:190.154 min
#      step:200, loss:0.000, time:190.996 min
#      step:300, loss:0.005, time:191.860 min
#      step:400, loss:0.001, time:192.709 min
#      step:500, loss:0.000, time:193.559 min
#      step:600, loss:0.000, time:194.431 min
#      step:700, loss:0.002, time:195.293 min
#      step:800, loss:0.002, time:196.159 min
#      step:900, loss:0.002, time:197.009 min
#
# Epoch 26/999
# ----------
#      step:0, loss:0.000, time:197.338 min
#      step:100, loss:0.000, time:198.211 min
#      step:200, loss:0.001, time:199.078 min
#      step:300, loss:0.000, time:199.922 min
#      step:400, loss:0.000, time:200.770 min
#      step:500, loss:0.000, time:201.641 min
#      step:600, loss:0.000, time:202.510 min
#      step:700, loss:0.000, time:203.368 min
#      step:800, loss:0.004, time:204.213 min
#      step:900, loss:0.001, time:205.061 min
#
# Epoch 27/999
# ----------
#      step:0, loss:0.000, time:205.383 min
#      step:100, loss:0.000, time:206.247 min
#      step:200, loss:0.000, time:207.108 min
#      step:300, loss:0.001, time:207.975 min
#      step:400, loss:0.000, time:208.833 min
#      step:500, loss:0.000, time:209.684 min
#      step:600, loss:0.000, time:210.539 min
#      step:700, loss:0.000, time:211.368 min
#      step:800, loss:0.000, time:212.216 min
#      step:900, loss:0.000, time:213.073 min
#
# Epoch 28/999
# ----------
#      step:0, loss:0.000, time:213.402 min
#      step:100, loss:0.001, time:214.258 min
#      step:200, loss:0.001, time:215.108 min
#      step:300, loss:0.004, time:215.977 min
#      step:400, loss:0.000, time:216.846 min
#      step:500, loss:0.000, time:217.697 min
#      step:600, loss:0.000, time:218.556 min
#      step:700, loss:0.000, time:219.398 min
#      step:800, loss:0.001, time:220.250 min
#      step:900, loss:0.000, time:221.077 min
#
# Epoch 29/999
# ----------
#      step:0, loss:0.002, time:221.403 min
#      step:100, loss:0.000, time:222.237 min
#      step:200, loss:0.000, time:223.085 min
#      step:300, loss:0.000, time:223.948 min
#      step:400, loss:0.001, time:224.809 min
#      step:500, loss:0.000, time:225.675 min
#      step:600, loss:0.004, time:226.541 min
#      step:700, loss:0.001, time:227.390 min
#      step:800, loss:0.004, time:228.258 min
#      step:900, loss:0.000, time:229.128 min
#
# Epoch 30/999
# ----------
#      step:0, loss:0.000, time:229.454 min
#      step:100, loss:0.000, time:230.308 min
#      step:200, loss:0.000, time:231.169 min
#      step:300, loss:0.000, time:232.040 min
#      step:400, loss:0.001, time:232.892 min
#      step:500, loss:0.001, time:233.750 min
#      step:600, loss:0.002, time:234.618 min
#      step:700, loss:0.001, time:235.486 min
#      step:800, loss:0.000, time:236.356 min
#      step:900, loss:0.000, time:237.226 min
#
# Epoch 31/999
# ----------
#      step:0, loss:0.001, time:237.554 min
#      step:100, loss:0.000, time:238.417 min
#      step:200, loss:0.000, time:239.285 min
#      step:300, loss:0.002, time:240.145 min
#      step:400, loss:0.000, time:241.015 min
#      step:500, loss:0.000, time:241.884 min
#      step:600, loss:0.000, time:242.752 min
#      step:700, loss:0.002, time:243.614 min
#      step:800, loss:0.000, time:244.483 min
#      step:900, loss:0.000, time:245.348 min
# Training complete in 245m 40s
# Best val Acc: 0.000010

# %%
# test_img = cv2.imread(BASE_DIR + 'train/0/1.jpg')
# test_img = cv2.resize(test_img, (input_size,input_size), interpolation=cv2.INTER_CUBIC)
# test_img = np.moveaxis(test_img,2,0)
# test_img = torch.FloatTensor(test_img).cuda().unsqueeze(0)
# print(test_img.shape)

# outputs = model(test_img)
# print(outputs.shape)
# print(outputs)
# Out:
# Connection to remote host was lost.
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
# [Errno 111] Connection refused
# on_close() takes 1 positional argument but 3 were given
